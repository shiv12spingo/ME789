# %%
def Horner(x0,a):
  N = len(a) - 1
  i = N-1
  b = [0]*(N+1)
  b[-1] = a[-1]
  while(i>=0):
    b[i] = a[i] + (b[i+1]*x0)
    i-=1
  P1 = b[0]
  k = 1
  P2 = 0
  while(k<=N):
    P2+=b[k]*(x0**(k-1))
    k+=1
  return (P1,P2)

# %%
x0 = -2
a = [-4, 3, -3, 0, 2]
Horner(x0,a)
# Out:
# (10, -49)
